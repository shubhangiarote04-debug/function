# %%
#Q1
def num(n):
    num=0
    rev=0
    largest=0
    while n>0:
        digit=n%10
        rev=rev*10+digit
        n//=10
        digit*=n
    print(rev)
l=[123]
result=map(num,l)
print(list(result))
# Out:
# 321
# [None]

# %%
#Q2
l=[200,324,40,45,56,89]
def digit(x):
    a=x//10
    return a%x
result=map(digit,l)
print(list(result))
# Out:
# [20, 3, 4, 4, 5, 8]

# %%
#Q3
from functools import reduce
list=[3,5,7]
def num(x,y):
    return (x-y)+(x+y)
result=reduce(num,list)
print(result)
# Out:
# 12

# %%
#Q4
a=[10,20,30,40]
def num(n):
    count=0
    return n*n
    for i in range(n):
        count+=i
    print(count)
    if count%n==0:
        return n
result=map(num,a)
print(tuple(result))
# Out:
# (100, 400, 900, 1600)

# %%
#Q5

# %%
#Q6
a=[2,3,4]
def factorial():
    fact=1
    a=int(input("enter a number"))
    for i in range(1,a+1):
        fact*=i
    print("factorial of num",fact)
factorial()
# Out:
# enter a number 5
# factorial of num 120

# %%
#Q7
l=[2,3,4,5]
def num(x):
    a=(1/2)
    return a
result=map(num,l)
print(list(result))
# Out:
# [4.0, 6.0, 8.0, 10.0]

# %%
#Q8
def prime(n):
    if n<=0:
        return False
    for i in range(2,n):
        if n%i==0:
            return False
    return True
prime(2)
# Out:
# True

# %%
#Q9

# %%
#Q10
l=[12,33,45,55,60,19,40]
def digit(x):
    sum=0
    count=0
    if sum==l:
        sum+=1
    if x%2==0  or x%2!=0:
          return x
result=map(digit,l)
print(list(result))
# Out:
# [12, 33, 45, 55, 60, 19, 40]

# %%
#Q11
l1=[2,3,4,5]
def digit():
    sum=0
    for i in range(1,n+1):
        sum+=1
        return sum
result=map(digit,l1)
print(list(result))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 9
#       7         return sum
#       8 result=map(digit,l1)
# ----> 9 print(list(result))
#
# TypeError: digit() takes 0 positional arguments but 1 was given

# %%
#Q12
a=[2,3,4,56]
def num(x):
# Out:
#   Cell In[32], line 5
#
#     ^
# _IncompleteInputError: incomplete input

# %%
#Q13
def is_prime():
    n=int(input("enter a number"))
    if n<=0:
        return False
    for i in range(2,n):
        if n%i==0:
            
            return False
    return True
is_prime() 
def composite_num():
# Out:
# enter a number 19
# True

# %%
#Q14
l=[123]
def middle(x):
    num=0
    rev=0
    while x>0:
        digit=x%10
        rev=rev*10+digit
        x//=10
    print(rev)
result=map(middle,l)
print(list(result))
# Out:
# 321
# [None]

# %%
#Q15
def num(x):
   a=int(input("enter a number"))
